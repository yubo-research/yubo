# %%
import sys
print(sys.executable)
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /tmp/yes/envs/bbo/bin/python

# %%
# !sh ./experiments/juju_arm.sh
# Out:
# Start f:ackley-2d mtv 100 arms 3 Iters exp_test
# 100%|████████████████████████████████████████| 30/30 [4:26:43<00:00, 533.46s/it]
# Finish
# Start f:ackley-10d mtv 100 arms 3 Iters exp_test
# 100%|████████████████████████████████████████| 30/30 [8:00:11<00:00, 960.38s/it]
# Finish
