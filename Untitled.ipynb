# %%
import sys
print(sys.executable)
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /home/juju/miniconda3/envs/bbo/bin/python

# %%
# !sh ./experiments/juju_arm.sh
# Out:
# Start f:ackley-2d mtv 1 arms 3 Iters exp_test
# 100%|███████████████████████████████████████████| 30/30 [01:09<00:00,  2.33s/it]
# Finish
# Start f:ackley-10d mtv 1 arms 3 Iters exp_test
# 100%|███████████████████████████████████████████| 30/30 [01:34<00:00,  3.16s/it]
# Finish
# Start f:ackley-2d mtv 3 arms 3 Iters exp_test
# 100%|███████████████████████████████████████████| 30/30 [04:42<00:00,  9.41s/it]
# Finish
# Start f:ackley-10d mtv 3 arms 3 Iters exp_test
# 100%|███████████████████████████████████████████| 30/30 [05:50<00:00, 11.70s/it]
# Finish
# Start f:ackley-2d mtv 10 arms 3 Iters exp_test
# 100%|███████████████████████████████████████████| 30/30 [12:01<00:00, 24.04s/it]
# Finish
# Start f:ackley-10d mtv 10 arms 3 Iters exp_test
# 100%|███████████████████████████████████████████| 30/30 [19:54<00:00, 39.80s/it]
# Finish
# Start f:ackley-2d mtv 30 arms 3 Iters exp_test
# 100%|███████████████████████████████████████████| 30/30 [28:31<00:00, 57.04s/it]
# Finish
# ...
